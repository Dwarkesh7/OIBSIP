# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Load Data:

# %%
# Assuming your data is in a CSV file named 'sales_data.csv'
data = pd.read_csv('Advertising.csv')

# %% [markdown]
# #Prepare Data:

# %%
X = data[['TV', 'Radio', 'Newspaper']]  # Features
y = data['Sales']  # Target variable

# %% [markdown]
# #Split Data:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# #Train the Model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Make Predictions

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([10.05739563,  7.4522807 ,  7.0197076 , 24.08029725, 12.01786259,
#         6.53793858, 12.78286918, 15.10974587, 10.76974013, 16.34357951,
#        22.88297477,  9.12924467, 10.46455672, 15.48743552, 11.58555633,
#        12.17296914, 18.76551502, 10.78318566, 15.90515992, 17.30651279,
#        24.06692057,  9.59834224, 15.13512211, 12.38591525,  5.71360885,
#        15.24749314, 12.29402334, 20.9421167 , 13.40991558,  9.04348832,
#        12.89239415, 21.40272028, 18.13802209, 21.17320803,  6.56974433,
#         6.14114206,  7.89018394, 13.01541434, 14.68953791,  6.18835143])

# %% [markdown]
# #Evaluate the Model

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 4.402118291449685

# %%
# Exploratory Data Analysis (EDA)
# Plotting the distribution of the target variable 'Sales'
plt.figure(figsize=(10, 6))
sns.histplot(data['Sales'], kde=True, bins=30)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualizing the relationships between features and target variable
# Scatter plots for TV, Radio, and Newspaper against Sales
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.scatterplot(x=data['TV'], y=data['Sales'])
plt.title('Sales vs TV')

plt.subplot(1, 3, 2)
sns.scatterplot(x=data['Radio'], y=data['Sales'])
plt.title('Sales vs Radio')

plt.subplot(1, 3, 3)
sns.scatterplot(x=data['Newspaper'], y=data['Sales'])
plt.title('Sales vs Newspaper')

plt.tight_layout()
plt.show()

# %%
# Pairplot to visualize the pairwise relationships
sns.pairplot(data)
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(10, 6))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Building the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Making predictions
y_pred = model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation:")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Model Evaluation:
# Mean Squared Error (MSE): 4.402118291449685
# R-squared (R2 ): 0.8601145185017868

# %%
# Plotting the predictions vs actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.show()

# %% [markdown]
# # Summary

# %%
print("\nSummary of Findings:")
print("- The dataset contains information on advertising spend on TV, Radio, and Newspaper, and the corresponding Sales.")
print("- The dataset does not have any missing values.")
print("- Sales seem to have a positive correlation with TV and Radio advertising spend.")
print("- Newspaper advertising spend does not show a strong correlation with Sales.")
print("- The Linear Regression model was built to predict Sales based on advertising spend.")
print(f"- The Mean Squared Error of the model is {mse:.2f}.")
print(f"- The R-squared value of the model is {r2:.2f}, indicating that the model explains {r2*100:.2f}% of the variance in Sales.")
# Out:
# Summary of Findings:
# - The dataset contains information on advertising spend on TV, Radio, and Newspaper, and the corresponding Sales.
# - The dataset does not have any missing values.
# - Sales seem to have a positive correlation with TV and Radio advertising spend.
# - Newspaper advertising spend does not show a strong correlation with Sales.
# - The Linear Regression model was built to predict Sales based on advertising spend.
# - The Mean Squared Error of the model is 4.40.
# - The R-squared value of the model is 0.86, indicating that the model explains 86.01% of the variance in Sales.
